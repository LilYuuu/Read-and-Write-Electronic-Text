# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url = "https://www.nytimes.com/"

# %%
r = requests.get(url)

# %%
soup = BeautifulSoup(r.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <meta charset="utf-8"/>
# <title data-rh="true">The New York Times - Breaking News, US News, World News and Videos</title>
# ...

# %%
articles = soup.select("script")

# %%
articles
# Out:
# []

# %%
import requests as req
import time
API_KEY='g0p4CKl33ZfkMMjHn1GVW5UTEsDnQjMC' # your API key
# TOPIC='Technology' # keyword

# %%
# for i in range(10):
#   url='https://api.nytimes.com/svc/search/v2/articlesearch.json?q='+TOPIC+'&api-key='+API_KEY+'&page='+str(i)
url= "https://api.nytimes.com/svc/topstories/v2/home.json?api-key="+ API_KEY
response = req.get(url).json()
results = response['results'][:10]

# %%
results
# Out:
# [{'section': 'business',
#   'subsection': '',
#   'title': 'U.S. on Track to Add $19 Trillion in New Debt Over 10 Years',
#   'abstract': 'Congressional Budget Office projections released on Wednesday suggested rising interest rates and bipartisan spending bills are adding to deficits.',
#   'url': 'https://www.nytimes.com/2023/02/15/business/national-debt-biden.html',
#   'uri': 'nyt://article/539e2135-2140-5808-b383-06bbfbede654',
#   'byline': 'By Jim Tankersley and Alan Rappeport',
#   'item_type': 'Article',
#   'updated_date': '2023-02-15T17:58:04-05:00',
#   'created_date': '2023-02-15T14:00:15-05:00',
#   'published_date': '2023-02-15T14:00:15-05:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['United States Economy',
#    'Federal Budget (US)',
#    'Law and Legislation',
#    'National Debt (US)',
#    'United States Politics and Government',
#    'Inflation (Economics)',
#    'Stimulus (Economic)',
#    'Tax Credits, Deductions and Exemptions',
# ...

# %%
results[0]['title']
# Out:
# 'U.S. on Track to Add $19 Trillion in New Debt Over 10 Years'

# %%
results[0]['abstract']
# Out:
# 'Congressional Budget Office projections released on Wednesday suggested rising interest rates and bipartisan spending bills are adding to deficits.'

# %%
titles = []
abstracts = []

# %%
for each in results:
    titles.append(each['title'])
    abstracts.append(each['abstract'])

# %%
titles
# Out:
# ['U.S. on Track to Add $19 Trillion in New Debt Over 10 Years',
#  'U.S. on Track to Add $19 Trillion in New Debt Over 10 Years',
#  'C.B.O. Warns of Possible Default Between July and September',
#  'How a Fog of Questions Over a Spy Balloon and U.F.O.s Fed a Diplomatic Crisis',
#  'China Accuses U.S. of Flying Balloons Over Xinjiang and Tibet',
#  'Russian balloons floating over Kyiv were shot down, city officials say.',
#  'Moscow’s Military Capabilities Are in Question After Failed Battle for Ukrainian City',
#  'In the Wake of Tragedy, Balancing Freedom and Safety at Michigan State',
#  'In Ohio Town Where Train Derailed, Anxiety and Distrust Are Running Deep',
#  'What Toxic Chemicals Were Aboard the Derailed Train in Ohio?',
#  'Was Pablo Neruda Murdered?']

# %%
abstracts
# Out:
# ['Congressional Budget Office projections released on Wednesday suggested rising interest rates and bipartisan spending bills are adding to deficits.',
#  'The nonpartisan budget office also said that if tax receipts fall short of projections, and Congress fails to act on the debt limit, the U.S. could run out of cash before July.',
#  'U.S. officials now suspect that the balloon was sent to spy on bases in Guam and Hawaii and that other downed objects were not surveillance machines. Washington’s evolving view reflects U.S. and Chinese difficulties in discerning each other’s intentions.',
#  'The accusation came days after Beijing claimed that the United States had sent airships over China multiple times, ramping up tensions between the two superpowers.',
#  'Russia “uses such flying objects for reconnaissance or to confuse air defense systems,” the spokesman for the Ukrainian air force said.',
# ...

# %%
import random

# %%
l_titles = []
for t in titles:
    l_titles.append(t.split())

# %%
l_titles
# Out:
# [['U.S.',
#   'on',
#   'Track',
#   'to',
#   'Add',
#   '$19',
#   'Trillion',
#   'in',
#   'New',
#   'Debt',
#   'Over',
#   '10',
#   'Years'],
#  ['U.S.',
#   'on',
#   'Track',
#   'to',
#   'Add',
#   '$19',
#   'Trillion',
#   'in',
#   'New',
#   'Debt',
#   'Over',
#   '10',
#   'Years'],
#  ['C.B.O.',
#   'Warns',
#   'of',
#   'Possible',
#   'Default',
#   'Between',
#   'July',
#   'and',
#   'September'],
#  ['How',
#   'a',
#   'Fog',
#   'of',
#   'Questions',
#   'Over',
#   'a',
#   'Spy',
#   'Balloon',
#   'and',
#   'U.F.O.s',
#   'Fed',
#   'a',
#   'Diplomatic',
#   'Crisis'],
#  ['China',
#   'Accuses',
#   'U.S.',
#   'of',
#   'Flying',
#   'Balloons',
#   'Over',
#   'Xinjiang',
#   'and',
#   'Tibet'],
#  ['Russian',
#   'balloons',
#   'floating',
#   'over',
#   'Kyiv',
#   'were',
#   'shot',
#   'down,',
#   'city',
#   'officials',
#   'say.'],
#  ['Moscow’s',
#   'Military',
#   'Capabilities',
#   'Are',
#   'in',
#   'Question',
#   'After',
# ...

# %%
new_title = " ".join([random.choice(each) for each in l_titles])
new_title
# Out:
# 'Add U.S. Warns Spy Balloons officials for Wake Anxiety Chemicals Was'

# %%
l_abstracts = []
for a in abstracts:
    l_abstracts.append(a.split())

# %%
for each in l_abstracts:
    idx = random.randint(0, 5)
    print(" ".join(each[idx : (idx + random.randint(3,5))]))
# Out:
# released on Wednesday suggested
# office also said that
# officials now suspect that
# Beijing claimed that
# for reconnaissance or to confuse
# on Vuhledar, viewed
# elementary, middle and
# two weeks after
# materials used in plastics,
# has long been suspicion that

# %%
for each in l_titles:
    idx = random.randint(0, 5)
    if len(each) >= 9:
        print(" ".join(each[idx : (idx + random.randint(2,4))]))
    else:
        print(" ".join(each))
# Out:
# Track to Add
# U.S. on Track
# Default Between July and
# Questions Over a Spy
# Balloons Over Xinjiang and
# Kyiv were shot
# Moscow’s Military
# Balancing Freedom and Safety
# Where Train
# What Toxic
# Was Pablo Neruda Murdered?
